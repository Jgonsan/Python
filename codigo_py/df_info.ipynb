# %%
dicionario = {
    'nomes': ['Weg', 'Petrobras', 'Vale', 'Petrobras', 'Lojas Renner'],
    'tickers': ['WEG3', 'PETR4', 'VALE3', 'PETR4', 'LREN3'],
    'cotacoes': [20, 30, 40, 12, 35],
    'preco_sobre_lucro': [25, 6, 12, 7, 25],
    'volumes': [5000, 1000, 4000, 7000, 1200]
}

df_info_empresas = pd.DataFrame(dicionario)
df_info_empresas = df_info_empresas.set_index('tickers')
df_info_empresas.columns = ['nomes', 'precos', 'preco_sobre_lucro', 'volumes']
df_info_empresas['lpa'] = df_info_empresas['precos'] / df_info_empresas['preco_sobre_lucro']
dolar = 5.25
df_info_empresas['precos_dolar'] = df_info_empresas['precos'] / dolar
df_info_empresas['nomes'] = df_info_empresas['nomes'].map(lambda x: x.lower())
df_info_empresas['precos'] = df_info_empresas['precos'].map(lambda x: 'R$ ' + str(x))
df_info_empresas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       1 dicionario = {
#       2     'nomes': ['Weg', 'Petrobras', 'Vale', 'Petrobras', 'Lojas Renner'],
#       3     'tickers': ['WEG3', 'PETR4', 'VALE3', 'PETR4', 'LREN3'],
#    (...)      6     'volumes': [5000, 1000, 4000, 7000, 1200]
#       7 }
# ----> 9 df_info_empresas = pd.DataFrame(dicionario)
#      10 df_info_empresas = df_info_empresas.set_index('tickers')
#      11 df_info_empresas.columns = ['nomes', 'precos', 'preco_sobre_lucro', 'volumes']
#
# NameError: name 'pd' is not defined
